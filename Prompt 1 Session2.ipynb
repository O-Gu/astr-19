# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x= np.linspace(0,1,num=100)
f_x= np.exp(x)

# %%
y= np.exp(x)

plt.plot(x,y,'r',label='AWSOMENESS')
plt.xlabel("Time [milliseconds]")
plt.ylabel("AWESOMENESS")
plt.show()

plt.savefig("prompt_1",bbox_inches="tight",facecolor="white")
